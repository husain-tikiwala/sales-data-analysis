# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data=pd.read_csv("sales_data.csv")

# %%
data.head()
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %%
data=data.dropna()

# %% [markdown]
# #scatter

# %%
x=data["quantity"].unique()
y=data.groupby("quantity")["revenue"].sum()

# %%
plt.scatter(x,y,marker="^")
plt.show()

# %%
x1=data["price"].unique()
y1=data.groupby("price")["revenue"].sum()

# %%
plt.scatter(x,y,marker="^")
plt.scatter(x1,y1,marker="*")
plt.legend(["quantity","price"])
plt.show()

# %%
sns.scatterplot(data,x="price",y="revenue")
# Out:
# <Axes: xlabel='price', ylabel='revenue'>

# %%
sns.scatterplot(data,x="quantity",y="revenue")
# Out:
# <Axes: xlabel='quantity', ylabel='revenue'>

# %% [markdown]
# #Histogram

# %%
sns.histplot(data,x="quantity")
# Out:
# <Axes: xlabel='quantity', ylabel='Count'>

# %% [markdown]
# #Subplots

# %%
plt.subplots(2,2)
plt.subplot(2,2,1)
sns.histplot(data,x="quantity")

plt.subplot(2,2,2)
sns.scatterplot(data,x="quantity",y="revenue")

plt.subplot(2,2,3)
sns.scatterplot(data,x="price",y="revenue")
# Out:
# <Axes: xlabel='price', ylabel='revenue'>

# %%
figure, ax = plt.subplots(4,4)
figure.set(size_inches=(12,8))
ax[0,0].pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x22ac76196a0>,
# ...
#  [Text(1.0999441814079074, 0.0110814162853224, ''),
#   Text(1.099603088267654, 0.029547390277959416, ''),
#   Text(1.0892070159648735, 0.15371426860540946, ''),
#   Text(0.9725883167356248, 0.513879330338713, ''),
#   Text(0.48016734046938225, 0.9896662695810949, ''),
#   Text(-0.12836870381095664, 1.092484084955884, ''),
#   Text(-0.6157816030967223, 0.911489449904732, ''),
#   Text(-1.068478213397553, 0.26144656718873477, ''),
#   Text(-0.9934346886525734, -0.4723214153325726, ''),
#   Text(-0.3909618831466205, -1.0281774194789772, ''),
#   Text(0.37316652374726283, -1.0347689334118915, ''),
#   Text(0.6247423786336519, -0.9053711726906081, ''),
#   Text(0.8243852579417986, -0.7282780694818664, ''),
#   Text(0.9581163150874745, -0.5403823893903275, ''),
#   Text(1.022773643906784, -0.4048877292900328, ''),
#   Text(1.076530428913505, -0.22601379520574646, ''),
#   Text(1.092968988278587, -0.12417242311110162, ''),
# ...

# %%
sns.pairplot(data,hue="category")

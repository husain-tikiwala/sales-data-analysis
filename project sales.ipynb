# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("sales_data.csv")

# %%
df.head(5)
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %%
df.isnull().sum()
# Out:
# date        0
# product     0
# category    0
# price       2
# quantity    1
# revenue     1
# dtype: int64

# %%
df[df["price"].isnull()]
# Out:
#            date product     category  price  quantity  revenue
# 193  2022-07-11   Watch  Accessories    NaN      15.0   2250.0
# 320  2022-11-13  Wallet  Accessories    NaN      35.0   1050.0

# %%
df["price"][df["price"].isnull()]=df["revenue"]/df["quantity"]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2496\1785307646.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["price"][df["price"].isnull()]=df["revenue"]/df["quantity"]
# ...

# %%
df.isnull().sum()
# Out:
# date        0
# product     0
# category    0
# price       0
# quantity    1
# revenue     1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      369 non-null    object
#  1   product   369 non-null    object
#  2   category  369 non-null    object
#  3   price     369 non-null    float64
#  4   quantity  368 non-null    float64
#  5   revenue   368 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.4+ KB

# %%
df["quantity"][df["quantity"].isnull()]=df["revenue"]/df["price"]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2496\4101148637.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["quantity"][df["quantity"].isnull()]=df["revenue"]/df["price"]
# ...

# %%
df.isnull().sum()
# Out:
# date        0
# product     0
# category    0
# price       0
# quantity    0
# revenue     1
# dtype: int64

# %%
df["revenue"][df["revenue"].isnull()] = df["price"]*df["quantity"]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2496\3646136962.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["revenue"][df["revenue"].isnull()] = df["price"]*df["quantity"]
# ...

# %%
df.isnull().sum()
# Out:
# date        0
# product     0
# category    0
# price       0
# quantity    0
# revenue     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# date        0
# product     0
# category    0
# price       0
# quantity    0
# revenue     0
# dtype: int64

# %%
df["category"].unique()
# Out:
# array(['Electronics', 'Clothing', 'Accessories', 'Bags', 'Shoes',
#        'Clohting', 'Bgas', 'Shoeses'], dtype=object)

# %%
df["category"][df["category"]=='Bgas']=df["category"][df["category"]=='Bags']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2496\1749096811.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["category"][df["category"]=='Bgas']=df["category"][df["category"]=='Bags']
# ...

# %%
df["category"]=df["category"].fillna('Bags')

# %%
df["category"].unique()
# Out:
# array(['Electronics', 'Clothing', 'Accessories', 'Bags', 'Shoes',
#        'Clohting', 'Shoeses'], dtype=object)

# %%
df["category"][df["category"]=='Shoeses']=df["category"][df["category"]=='Shoes']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2496\1906894711.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["category"][df["category"]=='Shoeses']=df["category"][df["category"]=='Shoes']
# ...

# %%
df["category"]=df["category"].fillna('Shoes')

# %%
df["category"][df["category"]=='Clohting']=df["category"][df["category"]=='Clothing']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2496\2095861639.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["category"][df["category"]=='Clohting']=df["category"][df["category"]=='Clothing']
# ...

# %%
df["category"]=df["category"].fillna('Clothing')

# %%
df.tail(5)
# Out:
#            date     product     category  price  quantity  revenue
# 364  2022-12-27       Watch  Accessories  150.0       5.0    750.0
# 365  2022-12-28        Coat     Clothing  100.0       5.0    500.0
# 366  2022-12-29  Headphones  Electronics  100.0      10.0   1000.0
# 367  2022-12-30  Smartphone  Electronics  600.0      11.0   6600.0
# 368  2022-12-31      Hoodie     Clothing   40.0      30.0   1200.0

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      369 non-null    datetime64[ns]
#  1   product   369 non-null    object
#  2   category  369 non-null    object
#  3   price     369 non-null    float64
#  4   quantity  369 non-null    float64
#  5   revenue   369 non-null    float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 17.4+ KB

# %%
df.describe()
# Out:
#                                 date        price    quantity      revenue
# count                            369   369.000000  369.000000   369.000000
# mean   2022-07-01 15:05:21.951219456   210.569106   14.555556  2060.514905
# min              2022-01-01 00:00:00    20.000000    3.000000   300.000000
# 25%              2022-04-01 00:00:00    50.000000    8.000000   800.000000
# 50%              2022-07-02 00:00:00   100.000000   12.000000  1200.000000
# 75%              2022-10-01 00:00:00   200.000000   20.000000  2400.000000
# max              2022-12-31 00:00:00  1200.000000   50.000000  7200.000000
# std                              NaN   226.934800    8.586059  1908.335265

# %%
df["revenue"].sum()
# Out:
# np.float64(760330.0)

# %%
highest_revenue=df.groupby("product")["revenue"].sum()

# %%
df.groupby("product")["price"].mean()
# Out:
# product
# Backpack        50.0
# Coat           100.0
# Headphones     100.0
# Hoodie          40.0
# Jeans           50.0
# Laptop        1200.0
# Smartphone     600.0
# Smartwatch     200.0
# Sneakers        80.0
# Speaker         80.0
# T-Shirt         20.0
# Tablet         400.0
# Wallet          30.0
# Watch          150.0
# Name: price, dtype: float64

# %%
df.groupby("product")["quantity"].sum()
# Out:
# product
# Backpack       408.0
# Coat           338.0
# Headphones     180.0
# Hoodie         525.0
# Jeans          413.0
# Laptop           5.0
# Smartphone     724.0
# Smartwatch     304.0
# Sneakers       270.0
# Speaker        496.0
# T-Shirt       1005.0
# Tablet          45.0
# Wallet         440.0
# Watch          218.0
# Name: quantity, dtype: float64

# %%
df["quantity"].sum()
# Out:
# np.float64(5371.0)

# %%
avr=df["revenue"].sum()/df["quantity"].sum()

# %%
round(avr)
# Out:
# 142

# %%
df["quarter"]=df["date"].dt.quarter

# %%
df["category"].unique()
# Out:
# array(['Electronics', 'Clothing', 'Accessories', 'Bags', 'Shoes'],
#       dtype=object)

# %%
df
# Out:
#           date     product     category   price  quantity  revenue  quarter
# 0   2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0        1
# 1   2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0        1
# 2   2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0        1
# 3   2022-01-03  Headphones  Electronics   100.0      20.0   2000.0        1
# 4   2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0        1
# ..         ...         ...          ...     ...       ...      ...      ...
# 364 2022-12-27       Watch  Accessories   150.0       5.0    750.0        4
# 365 2022-12-28        Coat     Clothing   100.0       5.0    500.0        4
# 366 2022-12-29  Headphones  Electronics   100.0      10.0   1000.0        4
# 367 2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0        4
# 368 2022-12-31      Hoodie     Clothing    40.0      30.0   1200.0        4
#
# [369 rows x 7 columns]

# %%
df.groupby("quarter")["revenue"].sum()
# Out:
# quarter
# 1    182100.0
# 2    185970.0
# 3    197680.0
# 4    194580.0
# Name: revenue, dtype: float64

# %%
df.groupby("category")["revenue"].sum()
# Out:
# category
# Accessories    106700.0
# Bags            20400.0
# Clothing        95550.0
# Electronics    516080.0
# Shoes           21600.0
# Name: revenue, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,6))
barlabel=plt.bar(df["category"],df["revenue"])
plt.bar_label(barlabel,label_type="center")
plt.xlabel("category")
plt.title("category vs revenue")
plt.xticks(size=14,rotation=90)
plt.yticks(size=14,rotation=60)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.bar(df["category"],df["revenue"],color=["red","green","yellow","blue","purple","brown"])
plt.xlabel("category")
plt.title("category vs revenue")
plt.xticks(size=14,rotation=90)
plt.yticks(size=14,rotation=60)
plt.show()

# %%
plt.figure(figsize=(12,6))
barlabel=plt.bar(df["category"],df["revenue"],color=["red","green","yellow","blue","purple","brown"])
plt.bar_label(barlabel,label_type="center")
plt.xlabel("category")
plt.title("category vs revenue")
plt.xticks(size=14,rotation=90)
plt.yticks(size=14,rotation=60)
plt.show()

# %%
plt.figure(figsize=(12,6))
barlabel=plt.bar(df["product"].unique(),df.groupby("product")["revenue"].sum())
plt.bar_label(barlabel)
plt.xlabel("product")
plt.title("product vs revenue")
plt.xticks(size=14,rotation=90)
plt.yticks(size=14,rotation=60)
plt.show()

# %%
plt.figure(figsize=(12,6))
barlabel=plt.bar(df["category"].unique(),df.groupby("category")["quantity"].sum())
plt.bar_label(barlabel)
plt.xlabel("category")
plt.title("category vs quantity",size=50,color="red")
plt.xticks(size=14,rotation=90)
plt.yticks(size=14,rotation=60)
plt.show()

# %%
x=df["category"].unique()
y=df.groupby("category")["revenue"].sum()

# %%
y
# Out:
# category
# Accessories    106700.0
# Bags            20400.0
# Clothing        95550.0
# Electronics    516080.0
# Shoes           21600.0
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(12,6))
barlabel=plt.bar(df["category"].unique(),df.groupby("category")["revenue"].sum())
plt.bar_label(barlabel)
plt.xlabel("category")
plt.title("category vs revenue",size=50,color="red")
plt.xticks(size=14,rotation=90)
plt.yticks(size=14,rotation=60)
plt.show()

# %%
plt.figure(figsize=(12,6))
barlabel=plt.bar(df["quarter"].unique(),df.groupby("quarter")["revenue"].sum(),color="green")
plt.bar_label(barlabel)
plt.xlabel("quarter")
plt.title("quarter vs revenue",size=50,color="red")
plt.xticks(size=14,rotation=90)
plt.yticks(size=14,rotation=60)
plt.show()

# %%
barlabel=plt.bar(df["product"].unique(),df.groupby("product")["price"].mean(),color="green")
plt.bar_label(barlabel)
plt.xlabel("product")
plt.ylabel("avg price")
plt.xticks(rotation=90)
plt.yticks(rotation=60)
plt.title("product vs avg price")
# Out:
# Text(0.5, 1.0, 'product vs avg price')

# %%
barlabel=plt.bar(df["product"].unique(),df.groupby("product")["revenue"].mean(),color="green")
plt.bar_label(barlabel,rotation=90)
plt.xlabel("product")
plt.ylabel("avg revenue")
plt.xticks(rotation=90)
plt.yticks(rotation=60)
plt.title("product vs avg revenue")
# Out:
# Text(0.5, 1.0, 'product vs avg revenue')

# %%
plt.figure(figsize=(12,6))
barlabel=plt.bar(df["product"].unique(),df.groupby("product")["quantity"].sum(),color="red")
plt.bar_label(barlabel)
plt.xlabel("product")
plt.title("product vs quantity",size=50,color="orange")
plt.xticks(size=14,rotation=90)
plt.yticks(size=14,rotation=60)
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
movie=pd.read_csv("imdb-top-1000.csv")

# %%
movie . head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
movie.groupby("Genre")["Gross"].sum().sort_values(ascending=False)
# Out:
# Genre
# Drama        3.540997e+10
# Action       3.263226e+10
# Comedy       1.566387e+10
# Animation    1.463147e+10
# Adventure    9.496922e+09
# Crime        8.452632e+09
# Biography    8.276358e+09
# Mystery      1.256417e+09
# Horror       1.034649e+09
# Fantasy      7.827267e+08
# Family       4.391106e+08
# Film-Noir    1.259105e+08
# Western      5.822151e+07
# Thriller     1.755074e+07
# Name: Gross, dtype: float64

# %%
movie.groupby("Genre")

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB

# %%
movie.isnull().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Director           0
# Star1              0
# No_of_Votes        0
# Gross              0
# Metascore        157
# dtype: int64

# %%
k=movie.groupby("Genre")["IMDB_Rating"].max()
m=movie.groupby("Genre")
for i,j in m :
    if i==k:
        print(i)
        print(j)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14284\263428052.py in ?()
#       1 k=movie.groupby("Genre")["IMDB_Rating"].max()
#       2 m=movie.groupby("Genre")
#       3 for i,j in m :
# ----> 4     if i==k:
#       5         print(i)
#       6         print(j)
#
# c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
k=movie.groupby("Genre")["IMDB_Rating"].idxmax()
k
p=movie.loc[k]

# %%
p
# Out:
#                         Series_Title Released_Year  Runtime      Genre  \
# 2                    The Dark Knight          2008      152     Action
# 21                      Interstellar          2014      169  Adventure
# 23     Sen to Chihiro no kamikakushi          2001      125  Animation
# 7                   Schindler's List          1993      195  Biography
# 19                      Gisaengchung          2019      132     Comedy
# 1                      The Godfather          1972      175      Crime
# 0           The Shawshank Redemption          1994      142      Drama
# 688       E.T. the Extra-Terrestrial          1982      115     Family
# 321     Das Cabinet des Dr. Caligari          1920       76    Fantasy
# 309                    The Third Man          1949      104  Film-Noir
# 49                            Psycho          1960      109     Horror
# 69                           Memento          2000      113    Mystery
# ...

# %%
new=movie.groupby("Genre")["IMDB_Rating"].max()

# %%
movie.groupby("Genre")["IMDB_Rating"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 movie.groupby("Genre")["IMDB_Rating"]["Series_Title"]
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\base.py:234, in SelectionMixin.__getitem__(self, key)
#     232 def __getitem__(self, key):
#     233     if self._selection is not None:
# --> 234         raise IndexError(f"Column(s) {self._selection} already selected")
#     236     if isinstance(key, (list, tuple, ABCSeries, ABCIndex, np.ndarray)):
#     237         if len(self.obj.columns.intersection(key)) != len(set(key)):
#
# IndexError: Column(s) IMDB_Rating already selected

# %%
new
# Out:
# Genre
# Action       9.0
# Adventure    8.6
# Animation    8.6
# Biography    8.9
# Comedy       8.6
# Crime        9.2
# Drama        9.3
# Family       7.8
# Fantasy      8.1
# Film-Noir    8.1
# Horror       8.5
# Mystery      8.4
# Thriller     7.8
# Western      8.8
# Name: IMDB_Rating, dtype: float64

# %%
new.max()
# Out:
# np.float64(9.3)

# %%
movie["Genre"].unique()
# Out:
# array(['Drama', 'Crime', 'Action', 'Biography', 'Western', 'Comedy',
#        'Adventure', 'Animation', 'Horror', 'Mystery', 'Film-Noir',
#        'Fantasy', 'Family', 'Thriller'], dtype=object)

# %%
new.min()
# Out:
# np.float64(7.8)

# %%
new=movie.groupby('Genre')['IMDB_Rating'].transform("max")
top=movie[movie["IMDB_Rating"]==new].reset_index(drop=True)

# %%
top
# Out:
#                            Series_Title Released_Year  Runtime      Genre  \
# 0              The Shawshank Redemption          1994      142      Drama
# 1                         The Godfather          1972      175      Crime
# 2                       The Dark Knight          2008      152     Action
# 3                      Schindler's List          1993      195  Biography
# 4       Il buono, il brutto, il cattivo          1966      161    Western
# 5                          Gisaengchung          2019      132     Comedy
# 6                          Interstellar          2014      169  Adventure
# 7         Sen to Chihiro no kamikakushi          2001      125  Animation
# 8                       La vita è bella          1997      116     Comedy
# 9                                Psycho          1960      109     Horror
# 10                              Memento          2000      113    Mystery
# 11                          Rear Window          1954      112    Mystery
# ...

# %%
final=top.groupby("Genre")["Series_Title"]
for i,j in final:
    print(i)
    print(j)
# Out:
# Action
# 2    The Dark Knight
# Name: Series_Title, dtype: object
# Adventure
# 6    Interstellar
# Name: Series_Title, dtype: object
# Animation
# 7    Sen to Chihiro no kamikakushi
# Name: Series_Title, dtype: object
# Biography
# 3    Schindler's List
# Name: Series_Title, dtype: object
# Comedy
# 5       Gisaengchung
# 8    La vita è bella
# Name: Series_Title, dtype: object
# Crime
# 1    The Godfather
# Name: Series_Title, dtype: object
# Drama
# 0    The Shawshank Redemption
# Name: Series_Title, dtype: object
# Family
# 14             E.T. the Extra-Terrestrial
# 15    Willy Wonka & the Chocolate Factory
# Name: Series_Title, dtype: object
# Fantasy
# 13    Das Cabinet des Dr. Caligari
# Name: Series_Title, dtype: object
# Film-Noir
# 12    The Third Man
# Name: Series_Title, dtype: object
# Horror
# 9    Psycho
# Name: Series_Title, dtype: object
# Mystery
# 10        Memento
# 11    Rear Window
# Name: Series_Title, dtype: object
# Thriller
# 16    Wait Until Dark
# ...
